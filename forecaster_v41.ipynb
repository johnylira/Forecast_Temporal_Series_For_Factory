# %% [markdown]
# ### Setup

# %% [markdown]
# #simulates the past
# #time section to calibrate (train) the models aimming the errors evaluation
# #Verify which the patterns in 2 years to see what the behavior each serie (product)
# evaluation_initial_month_calibration = (2021,3) #start
# evaluation_final_month_calibration = (2023,2) #end
#
# #simulates the future - see Action and Forecast Worksheet
# #time section to calculate the errors of the models trainned before.
# evaluation_initial_month_validation = (2023,3)
# evaluation_final_month_validation = (2023,3)
#
#
# #time section to calibrate (train) the models aimming the forecast
# #Verify which the patterns in 2 years to see what the behavior each serie (product)
# forecast_initial_month_calibration = (2021,4)
# forecast_final_month_calibration = (2023,3)
#
# #to do Forecast - see Forecast_All_Models Worksheet
# forecast_initial_month_validation = (2023,4)
# forecast_final_month_validation = (2025,3)
#
# #Considering short memory in last "move_average" months:
# move_average=3

# %%
# evaluation_initial_month_calibration = (2021,2) #start
# evaluation_final_month_calibration = (2023,1) #end
# evaluation_initial_month_validation = (2023,2)
# evaluation_final_month_validation = (2023,2)
# forecast_initial_month_calibration = (2021,3)
# forecast_final_month_calibration = (2023,2)
# forecast_initial_month_validation = (2023,3)
# forecast_final_month_validation = (2025,2)
# move_average=3

#simulates the past
#time section to calibrate (train) the models aimming the errors evaluation
#Verify which the patterns in 2 years to see what the behavior each serie (product)
evaluation_initial_month_calibration = (2022,12) #start
evaluation_final_month_calibration = (2024,7) #end

#simulates the future - see Action and Forecast Worksheet
#time section to calculate the errors of the models trainned before.
evaluation_initial_month_validation = (2024,8)
evaluation_final_month_validation = (2024,8)


#time section to calibrate (train) the models aimming the forecast
#Verify which the patterns in 2 years to see what the behavior each serie (product)
forecast_initial_month_calibration = (2023,1)
forecast_final_month_calibration = (2024,8)

#to do Forecast - see Forecast_All_Models Worksheet
forecast_initial_month_validation = (2024,9)
forecast_final_month_validation = (2026,8)

#Variables
Date='Date'
Key=['Centro', 'TG', 'FormatoNew']
values='Peso Total'

#Considering short memory in last "move_average" months:
move_average=3
periods=20#23
seasonal_periods=2 #11

debug=False

# %% [markdown]
# #### Importação de Biliotecas

# %%
import pandas as pd
import numpy as np
import asyncio
import datetime as dt
import scipy.signal.signaltools
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from statsmodels.tsa.arima.model import ARIMA
import pmdarima as pm
import gc
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from scipy.stats import t
import warnings
warnings.filterwarnings('ignore')#warnings.filterwarnings('default')
plt.rc("figure", figsize=(16, 8))
plt.rc("font", size=14)
xlsx = pd.ExcelFile(r'.\Carga BG.rev.01.xlsx', engine='openpyxl')
df = pd.read_excel(xlsx,sheet_name='Carga 1')
def get_reshaped_df(df,Date,Key,values):
    df = df.set_index(Date).sort_index().reset_index()
    df['Chave'] = df[Key].astype(str).agg('_'.join, axis=1)#df['Id Produzido'].astype(str) + '_' + df['BG Produzido'].astype(str) + '_' + df['roll_width'].astype(str) + '_' + df['Centro'].astype(str)
    df['Mês'] = df[Date].dt.month
    df['Ano'] = df[Date].dt.year
    grupo = df.pivot_table(values=values, index=['Ano', 'Mês'], columns=['Chave'], aggfunc=np.sum)
    return grupo
grupo = get_reshaped_df(df=df,
                        Date=Date,
                        Key=Key,
                        values=values)
grupo
# Out:
# Chave     B105_BRWTL127_1810  B105_BRWTL127_2050  B105_BRWTL127_2210  \
# Ano  Mês
# 2022 12                  NaN                 NaN                 NaN
# 2023 1                   NaN                 NaN                 NaN
#      2                   NaN                 NaN                 NaN
#      3                   NaN                 NaN                 NaN
#      4                   NaN                 NaN                 NaN
#      5                   NaN                 NaN                 NaN
#      6                   NaN                 NaN                 NaN
#      7                   NaN                 NaN                 NaN
#      8                   NaN                 NaN                 NaN
#      9                   NaN                0.97                 NaN
#      10                  NaN                 NaN                 NaN
#      11                  NaN                 NaN                 NaN
#      12                  NaN                 NaN                 NaN
# 2024 1                   NaN                 NaN                 NaN
#      2                   NaN                 NaN                 NaN
#      3                   NaN                 NaN                 NaN
#      4                  2.26                5.29                7.47
#      5                  1.99               18.45               14.67
#      6                  9.26               11.92                5.05
#      7                  4.04                9.67               17.68
#      8                  0.31                3.70                9.67
#
# Chave     B105_BRWTL150_1810  B105_BRWTL150_2050  B105_BRWTL150_2160  \
# Ano  Mês
# 2022 12                 0.40               11.79                2.48
# 2023 1                  0.80               12.82                 NaN
#      2                   NaN               23.03                 NaN
#      3                   NaN               35.77                 NaN
#      4                   NaN               14.99                 NaN
#      5                  7.96               41.96                 NaN
#      6                  6.41               30.98                 NaN
#      7                  8.69               19.02                 NaN
#      8                  6.77               34.73                 NaN
#      9                  1.29               24.70                 NaN
#      10                 4.40               15.68                0.14
#      11                 3.91               19.18                 NaN
#      12                 1.89               11.38                0.34
# 2024 1                  2.42               12.50                 NaN
#      2                  4.81               29.41                 NaN
#      3                  2.44               28.13                 NaN
#      4                  1.80               10.10                 NaN
#      5                   NaN                0.90                 NaN
#      6                   NaN                0.75                 NaN
#      7                   NaN                0.83                 NaN
#      8                   NaN                 NaN                 NaN
#
# Chave     B105_BRWTL150_2210  B105_HPK100_1600  B105_HPK100_1700  \
# Ano  Mês
# 2022 12                 7.31              7.69             17.63
# 2023 1                  7.13              8.93             33.80
#      2                 11.68             11.23             21.55
#      3                  7.90             13.68             21.93
#      4                  9.67             13.46              0.99
#      5                 11.40              7.51             12.33
#      6                  4.87             11.43             22.31
#      7                  5.99             19.06             12.18
#      8                  5.11             18.65             26.01
#      9                 11.28             22.16             29.93
#      10                13.83             18.13             37.19
#      11                 8.33             22.35             35.01
#      12                 0.59             14.88             26.89
# 2024 1                   NaN             16.85             35.68
#      2                 12.38             23.08             28.88
#      3                  9.96             21.18             44.10
#      4                  9.09             22.49             23.90
#      5                   NaN             19.99             13.86
#      6                   NaN             17.46             20.29
#      7                   NaN              7.55              8.21
#      8                   NaN              3.64             10.88
#
# Chave     B105_HPK100_1770  ...  B123_HPMFT160_2040  B123_HPMFT160_2100  \
# Ano  Mês                    ...
# 2022 12              13.14  ...               37.44               99.77
# 2023 1               23.51  ...               49.27              136.48
#      2                8.50  ...               71.56              126.67
#      3                3.05  ...               58.23              118.61
#      4                 NaN  ...               88.36              148.71
#      5                 NaN  ...               65.05              146.95
#      6                4.43  ...              101.79              165.29
#      7                4.36  ...               91.86              142.90
#      8               20.93  ...               80.26              182.11
#      9                 NaN  ...              126.84              157.98
#      10                NaN  ...               49.41              117.52
#      11               7.72  ...               67.81              120.47
#      12               2.41  ...               68.38               82.18
# 2024 1               26.35  ...               69.82               87.32
#      2                5.66  ...               53.08              103.45
#      3               20.53  ...               62.24               84.63
#      4               16.81  ...              110.23              132.40
#      5                5.62  ...               87.62              139.77
#      6                5.05  ...              101.66              131.32
#      7                 NaN  ...               90.27              175.00
#      8                 NaN  ...               38.16               14.53
#
# Chave     B123_HPMFT160_2180  B123_HPMFT160_2290  B123_HPMFT160_2310  \
# Ano  Mês
# 2022 12               173.91              162.63                 NaN
# 2023 1                162.28              228.00                 NaN
#      2                197.00              167.32                 NaN
#      3                155.26              120.86                 NaN
#      4                166.98              107.00                 NaN
#      5                244.07              236.71                 NaN
#      6                180.08              112.13                6.80
#      7                231.50              236.09                 NaN
#      8                206.94              163.54                 NaN
#      9                233.99              173.44                 NaN
#      10               241.26              198.31                 NaN
#      11               181.13              157.04                 NaN
#      12               128.48              125.04                 NaN
# 2024 1                192.08              112.90                 NaN
#      2                187.40              137.17                3.30
#      3                213.56              123.43                 NaN
#      4                140.69              150.32                3.64
#      5                172.44              185.78                 NaN
#      6                222.74              190.95                 NaN
#      7                219.13              138.74                 NaN
#      8                 77.50               30.79                 NaN
#
# Chave     B123_HPMFT160_2380  B123_HPMFT160_2390  B123_HPMFT160_2430  \
# Ano  Mês
# 2022 12                  NaN              201.03                 NaN
# 2023 1                   NaN              173.03                 NaN
#      2                   NaN              159.28                 NaN
#      3                   NaN              209.14                 NaN
#      4                   NaN              202.75                 NaN
#      5                   NaN              258.48                 NaN
#      6                   NaN              288.42                 NaN
#      7                   NaN              292.32                 NaN
#      8                   NaN              335.72                 NaN
#      9                   NaN              329.90                 NaN
#      10                  NaN              498.37                 NaN
#      11                  NaN              321.13                 NaN
#      12                  NaN              201.94                 NaN
# 2024 1                   NaN              258.16                 NaN
#      2                   NaN              268.17                 NaN
#      3                   NaN              282.72                 NaN
#      4                   NaN              283.41                 NaN
#      5                   NaN              245.70                 NaN
#      6                  1.89              379.76                 NaN
#      7                   NaN              317.24                7.55
#      8                   NaN              113.86                 NaN
#
# Chave     B123_HPMFT160_2440  B123_HPMFT160_2490
# Ano  Mês
# 2022 12               122.81              190.38
# 2023 1                108.25              105.73
#      2                 89.01              117.18
#      3                113.47              188.83
#      4                170.93              206.12
#      5                143.81              198.71
#      6                122.09              137.35
#      7                196.21              189.40
#      8                124.69              255.00
#      9                168.79              356.16
#      10               363.87              172.55
#      11               236.03              141.57
#      12               196.15              157.56
# 2024 1                174.25               72.69
#      2                128.32              127.06
#      3                151.04              105.02
#      4                132.92              109.30
#      5                138.95              170.95
#      6                185.50              165.43
#      7                153.63              136.34
#      8                 59.28               42.93
#
# [21 rows x 638 columns]

# %%
grupo=grupo.replace(0, np.NaN)
grupo.to_excel('.\Dados_mensais.xlsx',freeze_panes=(1,2))
sorted_data = grupo[grupo.isnull().sum().sort_values(ascending=True).index]
import missingno as msno
msno.matrix(sorted_data)
plt.show()
if debug==True:
    grupo=sorted_data.iloc[:,[0,200,300,304,-1,-10]].copy()
# grupo = grupo.iloc[:,0:1983]
colunas=grupo.columns
grupo#.loc[(2020,10):(2022,9),:]
# Out:
# Chave     B105_BRWTL127_1810  B105_BRWTL127_2050  B105_BRWTL127_2210  \
# Ano  Mês
# 2022 12                  NaN                 NaN                 NaN
# 2023 1                   NaN                 NaN                 NaN
#      2                   NaN                 NaN                 NaN
#      3                   NaN                 NaN                 NaN
#      4                   NaN                 NaN                 NaN
#      5                   NaN                 NaN                 NaN
#      6                   NaN                 NaN                 NaN
#      7                   NaN                 NaN                 NaN
#      8                   NaN                 NaN                 NaN
#      9                   NaN                0.97                 NaN
#      10                  NaN                 NaN                 NaN
#      11                  NaN                 NaN                 NaN
#      12                  NaN                 NaN                 NaN
# 2024 1                   NaN                 NaN                 NaN
#      2                   NaN                 NaN                 NaN
#      3                   NaN                 NaN                 NaN
#      4                  2.26                5.29                7.47
#      5                  1.99               18.45               14.67
#      6                  9.26               11.92                5.05
#      7                  4.04                9.67               17.68
#      8                  0.31                3.70                9.67
#
# Chave     B105_BRWTL150_1810  B105_BRWTL150_2050  B105_BRWTL150_2160  \
# Ano  Mês
# 2022 12                 0.40               11.79                2.48
# 2023 1                  0.80               12.82                 NaN
#      2                   NaN               23.03                 NaN
#      3                   NaN               35.77                 NaN
#      4                   NaN               14.99                 NaN
#      5                  7.96               41.96                 NaN
#      6                  6.41               30.98                 NaN
#      7                  8.69               19.02                 NaN
#      8                  6.77               34.73                 NaN
#      9                  1.29               24.70                 NaN
#      10                 4.40               15.68                0.14
#      11                 3.91               19.18                 NaN
#      12                 1.89               11.38                0.34
# 2024 1                  2.42               12.50                 NaN
#      2                  4.81               29.41                 NaN
#      3                  2.44               28.13                 NaN
#      4                  1.80               10.10                 NaN
#      5                   NaN                0.90                 NaN
#      6                   NaN                0.75                 NaN
#      7                   NaN                0.83                 NaN
#      8                   NaN                 NaN                 NaN
#
# Chave     B105_BRWTL150_2210  B105_HPK100_1600  B105_HPK100_1700  \
# Ano  Mês
# 2022 12                 7.31              7.69             17.63
# 2023 1                  7.13              8.93             33.80
#      2                 11.68             11.23             21.55
#      3                  7.90             13.68             21.93
#      4                  9.67             13.46              0.99
#      5                 11.40              7.51             12.33
#      6                  4.87             11.43             22.31
#      7                  5.99             19.06             12.18
#      8                  5.11             18.65             26.01
#      9                 11.28             22.16             29.93
#      10                13.83             18.13             37.19
#      11                 8.33             22.35             35.01
#      12                 0.59             14.88             26.89
# 2024 1                   NaN             16.85             35.68
#      2                 12.38             23.08             28.88
#      3                  9.96             21.18             44.10
#      4                  9.09             22.49             23.90
#      5                   NaN             19.99             13.86
#      6                   NaN             17.46             20.29
#      7                   NaN              7.55              8.21
#      8                   NaN              3.64             10.88
#
# Chave     B105_HPK100_1770  ...  B123_HPMFT160_2040  B123_HPMFT160_2100  \
# Ano  Mês                    ...
# 2022 12              13.14  ...               37.44               99.77
# 2023 1               23.51  ...               49.27              136.48
#      2                8.50  ...               71.56              126.67
#      3                3.05  ...               58.23              118.61
#      4                 NaN  ...               88.36              148.71
#      5                 NaN  ...               65.05              146.95
#      6                4.43  ...              101.79              165.29
#      7                4.36  ...               91.86              142.90
#      8               20.93  ...               80.26              182.11
#      9                 NaN  ...              126.84              157.98
#      10                NaN  ...               49.41              117.52
#      11               7.72  ...               67.81              120.47
#      12               2.41  ...               68.38               82.18
# 2024 1               26.35  ...               69.82               87.32
#      2                5.66  ...               53.08              103.45
#      3               20.53  ...               62.24               84.63
#      4               16.81  ...              110.23              132.40
#      5                5.62  ...               87.62              139.77
#      6                5.05  ...              101.66              131.32
#      7                 NaN  ...               90.27              175.00
#      8                 NaN  ...               38.16               14.53
#
# Chave     B123_HPMFT160_2180  B123_HPMFT160_2290  B123_HPMFT160_2310  \
# Ano  Mês
# 2022 12               173.91              162.63                 NaN
# 2023 1                162.28              228.00                 NaN
#      2                197.00              167.32                 NaN
#      3                155.26              120.86                 NaN
#      4                166.98              107.00                 NaN
#      5                244.07              236.71                 NaN
#      6                180.08              112.13                6.80
#      7                231.50              236.09                 NaN
#      8                206.94              163.54                 NaN
#      9                233.99              173.44                 NaN
#      10               241.26              198.31                 NaN
#      11               181.13              157.04                 NaN
#      12               128.48              125.04                 NaN
# 2024 1                192.08              112.90                 NaN
#      2                187.40              137.17                3.30
#      3                213.56              123.43                 NaN
#      4                140.69              150.32                3.64
#      5                172.44              185.78                 NaN
#      6                222.74              190.95                 NaN
#      7                219.13              138.74                 NaN
#      8                 77.50               30.79                 NaN
#
# Chave     B123_HPMFT160_2380  B123_HPMFT160_2390  B123_HPMFT160_2430  \
# Ano  Mês
# 2022 12                  NaN              201.03                 NaN
# 2023 1                   NaN              173.03                 NaN
#      2                   NaN              159.28                 NaN
#      3                   NaN              209.14                 NaN
#      4                   NaN              202.75                 NaN
#      5                   NaN              258.48                 NaN
#      6                   NaN              288.42                 NaN
#      7                   NaN              292.32                 NaN
#      8                   NaN              335.72                 NaN
#      9                   NaN              329.90                 NaN
#      10                  NaN              498.37                 NaN
#      11                  NaN              321.13                 NaN
#      12                  NaN              201.94                 NaN
# 2024 1                   NaN              258.16                 NaN
#      2                   NaN              268.17                 NaN
#      3                   NaN              282.72                 NaN
#      4                   NaN              283.41                 NaN
#      5                   NaN              245.70                 NaN
#      6                  1.89              379.76                 NaN
#      7                   NaN              317.24                7.55
#      8                   NaN              113.86                 NaN
#
# Chave     B123_HPMFT160_2440  B123_HPMFT160_2490
# Ano  Mês
# 2022 12               122.81              190.38
# 2023 1                108.25              105.73
#      2                 89.01              117.18
#      3                113.47              188.83
#      4                170.93              206.12
#      5                143.81              198.71
#      6                122.09              137.35
#      7                196.21              189.40
#      8                124.69              255.00
#      9                168.79              356.16
#      10               363.87              172.55
#      11               236.03              141.57
#      12               196.15              157.56
# 2024 1                174.25               72.69
#      2                128.32              127.06
#      3                151.04              105.02
#      4                132.92              109.30
#      5                138.95              170.95
#      6                185.50              165.43
#      7                153.63              136.34
#      8                 59.28               42.93
#
# [21 rows x 638 columns]

# %%
def apply_sarima(grupo,evaluation='yes'):
    treino = grupo.to_numpy().copy()
    colunas = grupo.columns.tolist()
    grupo = grupo.to_numpy()
    sarimas = []
    #sarimas=pd.DataFrame()
    for i in range(grupo.shape[1]):
        treino[:,i] = np.nan_to_num(grupo[:,i], nan=0)#.fillna(grupo.iloc[:,i].mean())#################################################################
        if np.isnan(treino[:,i]).sum() == 0:
            if evaluation=='yes':
                ###########grupo.iloc[:-1, i]

                start_year, start_month = evaluation_initial_month_calibration
                end_year, end_month = evaluation_final_month_calibration

                n_months = (end_year - start_year) * 12 + (end_month - start_month)

                #print(colunas[i])

                train_y = treino[:-1, :][:,i].copy()
        
                mask = ~np.isnan(train_y)
                train_y = train_y[mask]

                ##########yearmonth = grupo.index.to_list()[-1]
                tuples = []
                start_year=evaluation_initial_month_validation[0]
                end_year=evaluation_final_month_validation[0]
                start_month=evaluation_initial_month_validation[1]
                end_month=evaluation_final_month_validation[1]
                for year in range(start_year, end_year + 1):
                    start = start_month if year == start_year else 1
                    end = end_month if year == end_year else 12
                    for month in range(start, end + 1):
                        tuples.append((year, month))
                n_forecast = len(tuples)


            else:
                ############train_y = grupo.iloc[:, i]
                # Define as datas de início e fim com base nas variáveis de controle
                start_date = dt.datetime(*evaluation_initial_month_calibration, 1)
                end_date = dt.datetime(*forecast_final_month_validation, 1)
                dates = pd.date_range(start=start_date, end=end_date, freq='MS')
                forecast_initial_index_calibration = dates.get_loc(dt.datetime(*forecast_initial_month_calibration, 1))
                forecast_final_index_calibration = dates.get_loc(dt.datetime(*forecast_final_month_calibration, 1))
                #forecast_initial_index_validation = dates.get_loc(datetime.datetime(*forecast_initial_month_validation, 1))
                #forecast_final_index_validation = dates.get_loc(datetime.datetime(*forecast_final_month_validation, 1))
                train_y = treino[forecast_initial_index_calibration:forecast_final_index_calibration, i].copy()

                mask = ~np.isnan(train_y)
                train_y = train_y[mask]

                ############yearmonth = grupo.index.to_list()[-1]
                ############yearmonth = ((datetime.datetime(yearmonth[0], yearmonth[1], 1) + datetime.timedelta(days=31)).year,
                 ###########(datetime.datetime(yearmonth[0], yearmonth[1], 1) + datetime.timedelta(days=31)).month)
                tuples = []
                start_year=forecast_initial_month_validation[0]
                end_year=forecast_final_month_validation[0]
                start_month=forecast_initial_month_validation[1]
                end_month=forecast_final_month_validation[1]
                for year in range(start_year, end_year + 1):
                    start = start_month if year == start_year else 1
                    end = end_month if year == end_year else 12
                    for month in range(start, end + 1):
                        tuples.append((year, month))
                n_forecast = len(tuples)

            arima_model=pm.auto_arima(train_y, 
            #exogenous= train_X,
             start_p=0, start_q=0, 
             max_p=3, max_q=3, 
             #m=12,d=0,
             max_d=1,
             trace=False, 
             error_action='ignore', 
             suppress_warnings=True, 
             stepwise=True)
               
            ident = pd.MultiIndex.from_tuples(tuples,##################[yearmonth], 
                                              names=["Ano", "Mês"])
            try:
                k = arima_model.predict(n_periods=n_forecast)###################1)
                # print('agora',k,type(k))
            except ValueError:
                if evaluation == 'yes':
                    k=np.zeros(1)
                    # print('OBSERVE ESTA SÉRIE',i,'!!!!!!!!!!!!!!!!!')
                else:
                    k=np.zeros(24)
                    # print('OBSERVE ESTA SÉRIE',i,'!!!!!!!!!!!!!!!!!')
            pass
            #inte=pd.DataFrame(k,columns=[colunas[i]+"-R"],index=ident)
            #print(type(sarimas))
            #print(type(k))
            sarimas= np.concatenate((sarimas, k), axis=0)
            ultima_coluna=colunas[i]+"-R"
        else:
            sarimas[:,i]=np.nan_to_num(grupo[:,i], nan=0).mean()
            ultima_coluna=colunas[i]+"-M"
        #if sarimas.shape[0] == 1:
        if np.isnan(sarimas[i]).sum() == 0:
            sarimas[i]=np.nan_to_num(grupo[:,i], nan=0).mean()
        #else:
        #    print(sarimas)
        #    if np.isnan(sarimas[:,i]).sum() == 0:
        #        sarimas[:,i]=np.nan_to_num(grupo[:,i], nan=0).mean()
    sarimas[sarimas < 0] = 0
    return sarimas
sarimas = apply_sarima(grupo)
#sarimas.to_excel('.\Sarimas_results.xlsx')
sarimas
# Out:
# array([8.50476190e-01, 2.38095238e+00, 2.59714286e+00, 2.57095238e+00,
#        1.80309524e+01, 1.40952381e-01, 6.50095238e+00, 1.53047619e+01,
#        2.30261905e+01, 8.00333333e+00, 7.76666667e-01, 6.09733333e+01,
#        6.19285714e+01, 1.62380952e-01, 6.52209524e+01, 7.70476190e-01,
#        2.58595238e+01, 5.38666667e+00, 1.63085714e+01, 9.68380952e+00,
#        2.77485714e+01, 4.50952381e-01, 9.59047619e+00, 4.33657143e+01,
#        9.24338095e+01, 3.93333333e-01, 5.76190476e-02, 6.18371429e+01,
#        1.16761905e+01, 1.24952381e+00, 1.33738571e+02, 8.22090476e+01,
#        1.38571905e+02, 1.88857143e+00, 8.62823810e+01, 3.73095238e+00,
#        7.90161905e+01, 3.75952381e+00, 1.32021429e+02, 1.09333333e+00,
#        3.95761905e+00, 1.76160476e+02, 1.92380952e-01, 1.09709524e+01,
#        1.17761905e+00, 3.42857143e-02, 1.47571429e+01, 3.19047619e-01,
#        1.03071429e+01, 1.40357143e+01, 3.35238095e-01, 1.76495238e+01,
#        3.34338095e+01, 5.05595238e+01, 6.39038095e+01, 1.26142857e+00,
#        1.98523810e+00, 5.14928571e+01, 2.18914286e+01, 5.70476190e-01,
#        1.04955714e+02, 1.08539048e+02, 1.57721905e+02, 3.19523810e-01,
#        1.40363810e+02, 2.03333333e-01, 8.72271429e+01, 1.80958095e+02,
#        5.04385714e+01, 9.95714286e-01, 2.83827143e+02, 1.34285714e-01,
#        2.47666667e+00, 9.08571429e-01, 9.53333333e-01, 8.79952381e+00,
#        2.42952381e+00, 1.38714286e+00, 1.65623810e+01, 3.70000000e-01,
#        7.94571429e+00, 1.51238095e+00, 1.15714286e-01, 1.03809524e-01,
#        8.15476190e+00, 1.63676190e+01, 1.29242857e+01, 2.44909524e+01,
#        2.22733333e+01, 3.92380952e-01, 1.77719048e+01, 3.95266667e+01,
#        2.13923810e+01, 3.22204762e+01, 9.52380952e-03, 2.41428571e+00,
#        1.34238095e+00, 1.32476190e+00, 4.19047619e-02, 7.34428571e+00,
#        2.91900000e+01, 2.38095238e-03, 4.61861905e+01, 2.15577143e+02,
#        9.44357143e+01, 7.15866667e+01, 1.86190476e-01, 3.31323810e+01,
#        9.43619048e+00, 2.53428571e+00, 1.07063333e+02, 2.95904762e+00,
#        8.12447619e+01, 4.36666667e-01, 9.09680952e+01, 3.10761905e+00,
#        3.04971429e+01, 7.91047619e+00, 2.64828571e+01, 1.10933333e+01,
#        3.99042857e+01, 5.80000000e-01, 1.34319048e+01, 5.86004762e+01,
#        4.34852381e+01, 2.95095238e+00, 1.16190476e-01, 5.65166667e+01,
#        1.67971429e+01, 5.06190476e-01, 8.08223810e+01, 1.84619048e+00,
#        7.90142857e+01, 1.20690476e+02, 3.57142857e-02, 8.05714286e-01,
#        1.34528571e+02, 1.10095238e+00, 8.13585714e+01, 5.06190476e-01,
#        1.43612857e+02, 9.62142857e+00, 1.57142857e+00, 2.21084286e+02,
#        1.98671429e+01, 2.80809524e+00, 7.06666667e-01, 1.57190476e+00,
#        2.34547619e+01, 4.52857143e-01, 3.62857143e+00, 8.95238095e-02,
#        4.91176190e+01, 4.16666667e-01, 4.41723810e+01, 9.44076190e+01,
#        2.59904762e+00, 1.92380952e-01, 6.65461905e+01, 1.17942857e+01,
#        2.58571429e-01, 4.47171429e+01, 1.07961429e+02, 1.18214286e+01,
#        7.82490476e+01, 5.44423810e+01, 1.49304762e+02, 5.04971429e+01,
#        1.16190476e-01, 1.63333333e-01, 2.87619048e-01, 4.77142857e-01,
#        2.56952381e+01, 7.74371429e+01, 8.04809524e+00, 6.85714286e-02,
#        3.87095238e+00, 1.21142857e+00, 2.51285714e+00, 1.55571429e+00,
#        2.57142857e-01, 2.78571429e-01, 1.61476190e+00, 5.59047619e-01,
#        6.22380952e-01, 6.44285714e-01, 1.87619048e-01, 2.81190476e+00,
#        1.90476190e-01, 6.82409524e+01, 8.05333333e+00, 2.42880952e+01,
#        1.54490476e+01, 6.58428571e+00, 2.04000000e+00, 9.11095238e+00,
#        6.59857143e+00, 1.80714286e+01, 1.88333333e+01, 2.30633333e+01,
#        1.05852381e+01, 4.40233333e+01, 2.41904762e-01, 2.30409524e+01,
#        5.35476190e+00, 1.63118571e+02, 6.69842857e+01, 4.23809524e-02,
#        2.06210952e+02, 1.47653333e+02, 1.15090952e+02, 1.08420000e+02,
#        3.08224762e+02, 2.72200000e+01, 1.00047619e+01, 3.87190476e+00,
#        8.50057143e+01, 2.63347619e+01, 1.94285714e-01, 1.28314286e+01,
#        1.45238095e-01, 2.01901429e+02, 4.65962857e+02, 1.27095238e+00,
#        2.54131429e+02, 1.83321905e+02, 1.69068571e+02, 9.24700000e+01,
#        1.48179048e+02, 3.35109524e+01, 2.35339048e+02, 6.98571429e-01,
#        3.81909524e+01, 3.66723810e+01, 3.48595238e+01, 1.60323810e+01,
#        1.37219048e+01, 2.44333333e+01, 1.09890476e+01, 1.61171429e+01,
#        5.11123810e+01, 2.67409524e+01, 6.59571429e+00, 5.19523810e+00,
#        6.33333333e-02, 2.12809524e+00, 2.66047619e+00, 4.61904762e-02,
#        2.29785714e+01, 2.00495238e+01, 7.61904762e-03, 1.82123810e+01,
#        3.42314286e+01, 6.38900000e+01, 4.25285714e+01, 1.50304286e+02,
#        2.90476190e-01, 2.38642857e+01, 2.72809524e+00, 4.46619048e+00,
#        2.23809524e-02, 1.95032381e+02, 3.21151905e+02, 2.89047619e-01,
#        3.10836190e+02, 2.04574762e+02, 1.36092857e+02, 9.14242857e+01,
#        1.72804286e+02, 7.57619048e-01, 8.30761905e+01, 2.70526190e+02,
#        1.07666667e+00, 8.33590476e+01, 6.58709524e+01, 7.89800000e+01,
#        3.81019048e+01, 3.96885714e+01, 1.76190476e-02, 1.31904762e-01,
#        1.04761905e-01, 2.00952381e-01, 4.00000000e-02, 6.23809524e-01,
#        6.84285714e-01, 2.71428571e+00, 1.55238095e-01, 3.90571429e+00,
#        4.62761905e+00, 4.97666667e+00, 3.82857143e-01, 5.89761905e+00,
#        2.49047619e-01, 1.58338095e+01, 1.02857143e-01, 9.42857143e-02,
#        4.00000000e-02, 2.14285714e-02, 3.99095238e+00, 8.33333333e-02,
#        2.47666667e+00, 3.00904762e+00, 4.47857143e+00, 9.31904762e-01,
#        9.44523810e+00, 1.43809524e-01, 9.27142857e-01, 2.99523810e-01,
#        3.09428571e+00, 5.38095238e-02, 9.35714286e-01, 1.71428571e-02,
#        4.58571429e-01, 8.89661905e+01, 7.23809524e-02, 8.34857143e+01,
#        6.30138095e+01, 1.65774762e+02, 8.61247619e+01, 8.75376190e+01,
#        1.16500476e+02, 1.80619048e+02, 1.24238095e+00, 1.45023810e+01,
#        2.56780952e+01, 1.92314286e+01, 4.31904762e-01, 6.20000000e-01,
#        2.15580952e+01, 3.34153810e+02, 4.33333333e-01, 4.23825238e+02,
#        2.28487619e+02, 1.32433333e+01, 6.26669524e+02, 2.15787143e+02,
#        2.08888571e+02, 2.11570952e+02, 3.36120000e+02, 1.05971429e+02,
#        9.59723810e+01, 8.10628571e+01, 8.96385714e+01, 1.02738095e+01,
#        5.10957143e+01, 4.23142857e+00, 5.51466667e+01, 2.36666667e+00,
#        3.26504762e+01, 1.30323810e+01, 2.06428571e+00, 9.28476190e+00,
#        4.90380952e+01, 2.82627143e+02, 1.76666667e-01, 1.33333333e-01,
#        4.68089048e+02, 3.31904762e-01, 2.26189048e+02, 3.98184286e+02,
#        2.87469524e+02, 4.31053333e+02, 2.83622381e+02, 6.04459048e+02,
#        4.85476190e+00, 4.52523810e+00, 4.28252381e+01, 1.99523810e-01,
#        1.81957143e+01, 1.49343810e+02, 6.80952381e-02, 1.97777619e+02,
#        3.83809524e-01, 6.44671429e+01, 9.63138095e+01, 8.30561905e+01,
#        1.86547143e+02, 5.99933333e+01, 4.37846190e+02, 5.47047619e+00,
#        2.27749524e+02, 1.76666667e-01, 8.19290476e+01, 5.73595238e+01,
#        1.12346190e+02, 2.69595238e+01, 5.75623810e+01, 1.01829524e+02,
#        1.30091905e+02, 3.37619048e-01, 7.25047619e+00, 4.46142857e+00,
#        4.04761905e-02, 6.17904762e+00, 6.12095238e+00, 4.18333333e+00,
#        1.25809524e+00, 1.21679524e+02, 1.92857143e-01, 5.42857143e-02,
#        1.22257143e+02, 6.54761905e-01, 9.73247619e+01, 6.47619048e-02,
#        1.39800000e+01, 3.46666667e-01, 3.53440952e+02, 1.25439524e+02,
#        1.12500000e+02, 8.42857143e-02, 1.28807619e+02, 1.07190476e+00,
#        1.97720000e+02, 5.26666667e-01, 3.14904762e+00, 6.80238095e+00,
#        5.73804762e+01, 1.39380952e+01, 1.40761905e+00, 1.39666667e+00,
#        7.87666667e+00, 3.70152381e+01, 3.20000000e-01, 3.16596667e+02,
#        1.86190476e-01, 4.41326667e+02, 3.73809524e-01, 2.89047619e-01,
#        2.43681905e+02, 1.50952381e-01, 3.81000000e+00, 3.91574286e+02,
#        4.04761905e-02, 2.51009524e+02, 9.27142857e-01, 2.44820000e+02,
#        2.04176190e+02, 2.92380952e+00, 7.47620952e+02, 4.34761905e-01,
#        1.26933333e+01, 2.69523810e+00, 1.45714286e-01, 5.72238095e+00,
#        1.70714286e+00, 1.54752381e+01, 1.70952381e-01, 3.91506667e+02,
#        1.33333333e-01, 3.77142857e-01, 4.51420952e+02, 1.67920952e+02,
#        1.88809524e+00, 2.96582857e+02, 1.59124286e+02, 3.73406190e+02,
#        2.45078571e+02, 7.30476190e-01, 3.23531905e+02, 1.53333333e-01,
#        1.12380952e-01, 2.91904762e-01, 9.35714286e-01, 5.40476190e-01,
#        1.30952381e-01, 6.19047619e-02, 1.32857143e-01, 3.80952381e-02,
#        1.10476190e-01, 1.23857143e+00, 4.14285714e-01, 1.02238095e+00,
#        4.36666667e-01, 1.35714286e-01, 3.95238095e-02, 8.38095238e-02,
#        1.22571429e+00, 4.80476190e-01, 8.66190476e-01, 2.45238095e-01,
#        4.31428571e-01, 9.57142857e-02, 7.00000000e-01, 1.87190476e+00,
#        1.20238095e+00, 6.38904762e+00, 3.32857143e-01, 5.93523810e+00,
#        3.82380952e+00, 1.67366667e+01, 2.78095238e+00, 1.34900000e+01,
#        1.27619048e-01, 3.75714286e-01, 8.95095238e+00, 2.71904762e-01,
#        8.31428571e-01, 1.70057143e+01, 1.32904762e+00, 2.55695238e+01,
#        2.57176190e+01, 9.23809524e-01, 4.90476190e-02, 6.40638095e+01,
#        4.97157143e+01, 5.72004762e+01, 5.49461905e+01, 6.65404762e+01,
#        6.11428571e-01, 7.61428571e-01, 1.84728571e+01, 3.06076190e+01,
#        4.85047619e+00, 1.09133333e+01, 3.46985714e+01, 6.71428571e-02,
#        8.18485714e+01, 6.82957143e+01, 2.64761905e-01, 3.58904762e+00,
#        1.82039524e+02, 1.41150000e+02, 5.40476190e-01, 1.65312857e+02,
#        1.51469048e+02, 1.63390000e+02, 3.74761905e-01, 5.33333333e-02,
#        1.93380952e+00, 7.77547619e+01, 1.88209524e+01, 2.95342857e+01,
#        6.04857143e+00, 1.95161905e+01, 3.09523810e+00, 7.04761905e-02,
#        2.87804762e+01, 1.22834286e+02, 9.82428571e+00, 7.33142857e+00,
#        5.01452381e+01, 2.40952381e-01, 5.56600000e+01, 6.90314286e+01,
#        2.36190476e-01, 1.15058571e+02, 1.16454762e+02, 1.73449048e+02,
#        2.15744286e+02, 1.57354286e+02, 1.54504762e+02, 3.23000000e+00,
#        1.15503810e+02, 5.73333333e-01, 4.64285714e-01, 9.16100000e+01,
#        7.42380952e-01, 2.44190476e+00, 6.17438095e+01, 2.68171429e+01,
#        2.92547619e+01, 2.38233333e+01, 5.57261905e+01, 4.04171429e+01,
#        1.13880952e+01, 2.16766667e+01, 5.38047619e+00, 4.60019048e+01,
#        5.95442857e+01, 1.26428571e+00, 8.66819048e+01, 2.12700000e+01,
#        1.60009524e+01, 1.53156190e+02, 1.27200000e+01, 6.40476190e-01,
#        4.28057143e+01, 8.25571429e+00, 5.74328571e+01, 3.64523810e+00,
#        1.45676190e+01, 4.68571429e-01, 1.21952381e+00, 2.20147619e+01,
#        1.08095238e+00, 4.15519048e+01, 4.09552381e+01, 5.59523810e-01,
#        1.14285714e-01, 7.85714286e-02, 1.08912381e+02, 5.28095238e-01,
#        8.92466667e+01, 1.00476190e-01, 1.14689524e+02, 6.86300000e+01,
#        7.80000000e-01, 1.03214762e+02, 1.69571429e+00, 7.83333333e-01,
#        1.42304762e+01, 2.08676190e+01, 6.43523810e+00, 1.21004762e+01,
#        2.55285714e+00, 2.55323810e+01, 5.72276190e+01, 5.28380952e+01,
#        6.04761905e-01, 1.23576190e+01, 3.76190476e-02, 1.22137143e+02,
#        9.78171429e+01, 3.44761905e-01, 1.68571429e-01, 9.31133333e+01,
#        1.64761905e+00, 1.07638095e+02, 1.08607143e+02, 7.46666667e-01,
#        3.26985714e+01, 2.53774762e+02, 7.46333333e+00, 1.45428571e+00,
#        1.58362857e+02, 6.42380952e-01, 2.97666667e+00, 1.56326667e+02,
#        7.47304762e+01, 1.24479048e+02, 1.87067619e+02, 1.55151905e+02,
#        6.54285714e-01, 9.00000000e-02, 2.67644286e+02, 3.59523810e-01,
#        1.56190476e+02, 1.59345714e+02])

# %%
#Neste bloco é realizada a previsão dos valores para os 3 meses seguintes. A cada iteração é feito a previsão por grupo
#de produto. o Auto_Arima calcula os parâmetros ideias que melhor prevem o modelo. Depois de criado o modelo, ele pode 
#gerar a previsão dos valores futuros para quantos periodos forem necessários, nesse caso foram escolhidos 3 períodos.
#Por fim os valores previstos são exportados em uma planilha excel.

def get_tvalue(X,y):
    lm = LinearRegression()
    lm.fit(X,y)
    params = np.append(lm.intercept_,lm.coef_)
    predictions = lm.predict(X)

    #newX = pd.DataFrame({"Constant":np.ones(len(X))}).join(pd.DataFrame(X))
    #MSE = (sum((y-predictions)**2))/(len(newX)-len(newX.columns))

    # Note if you don't want to use a DataFrame replace the two lines above with
    newX = np.append(np.ones((len(X),1)), X, axis=1)
    MSE = (sum((y-predictions)**2))/(len(newX)-len(newX[0]))

    var_b = MSE*(np.linalg.inv(np.dot(newX.T,newX)).diagonal())
    sd_b = np.sqrt(var_b)
    ts_b = params/ sd_b
    '''
    p_values =[2*(1-scipy.stats.t.cdf(np.abs(i),(len(newX)-len(newX[0])))) for i in ts_b]
    
    sd_b = np.round(sd_b,3)
    ts_b = np.round(ts_b,3)
    p_values = np.round(p_values,3)
    params = np.round(params,4)

    myDF3 = pd.DataFrame()
    myDF3["Coefficients"],myDF3["Standard Errors"],myDF3["t values"],myDF3["Probabilities"] = [params,sd_b,ts_b,p_values]'''
    return(np.round(ts_b[1],0))#p_values[1])
def apply_regression(grupo,evaluation='yes'):
    if evaluation=='yes':
        ###########treino = grupo.iloc[:-1,:].copy()
        treino = grupo.loc[evaluation_initial_month_calibration:evaluation_final_month_calibration,:].copy()
        ##########yearmonth = grupo.index.to_list()[-1]
        tuples = []
        start_year=evaluation_initial_month_validation[0]
        end_year=evaluation_final_month_validation[0]
        start_month=evaluation_initial_month_validation[1]
        end_month=evaluation_final_month_validation[1]
        for year in range(start_year, end_year + 1):
            start = start_month if year == start_year else 1
            end = end_month if year == end_year else 12
            for month in range(start, end + 1):
                tuples.append((year, month))
        n_forecast = len(tuples)
        initial_month = evaluation_initial_month_calibration
    else:
        #############treino = grupo.iloc[:, :].copy()
        treino = grupo.loc[forecast_initial_month_calibration:forecast_final_month_calibration,:].copy()
        ########yearmonth = ((datetime.datetime(yearmonth[0], yearmonth[1], 1) + datetime.timedelta(days=31)).year,
         ##########(datetime.datetime(yearmonth[0], yearmonth[1], 1) + datetime.timedelta(days=31)).month)
        tuples = []
        start_year=forecast_initial_month_validation[0]
        end_year=forecast_final_month_validation[0]
        start_month=forecast_initial_month_validation[1]
        end_month=forecast_final_month_validation[1]
        for year in range(start_year, end_year + 1):
            start = start_month if year == start_year else 1
            end = end_month if year == end_year else 12
            for month in range(start, end + 1):
                tuples.append((year, month))
        n_forecast = len(tuples)
        initial_month = forecast_initial_month_calibration
    tam=treino.shape[1]
    idx = pd.MultiIndex.from_tuples(tuples,##########[yearmonth], 
                                              names=["Ano", "Mês"])
    
    if len(str(initial_month[1]))==1:
        string_yearmonth1=str(initial_month[0])+'0'+str(initial_month[1])+'01'
    else:
        string_yearmonth1=str(initial_month[0])+str(initial_month[1])+'01'
    
    dates = pd.date_range(string_yearmonth1, periods=periods, freq='MS')
    for i in range(2,13):
        treino['Dummy'+str(i)]=np.where(dates.month==i,1,0)
    treino
    treino['Tempo']=range(1,treino.shape[0]+1)

    previsao=pd.DataFrame()

    teste=pd.DataFrame(index=idx)
    
    if len(str(initial_month[1]))==1:
        string_yearmonth2=str(initial_month[0])+'0'+str(initial_month[1])+'01'
    else:
        string_yearmonth2=str(initial_month[0])+str(initial_month[1])+'01'
    dates = pd.date_range(string_yearmonth2, periods=n_forecast,freq='MS')#############1, freq='MS')
    for i in range(2,13):
        teste['Dummy'+str(i)]=np.where(dates.month==i,1,0)
    
    teste['Tempo'] = range(treino.shape[0]+1,treino.shape[0]+1+n_forecast)#########1)
    #teste['Future_trend'] = 1
    #teste['Interaction'] = teste['Future_trend']*teste['Tempo']
    #teste['Tempo']=range(36,36+25)
    X=treino[['Tempo', 'Dummy2','Dummy3','Dummy4','Dummy5','Dummy6','Dummy7','Dummy8','Dummy9','Dummy10','Dummy11', 'Dummy12']]
    #X=treino[['Dummy2','Dummy3','Dummy4','Dummy5','Dummy6','Dummy7','Dummy8','Dummy9','Dummy10','Dummy11', 'Dummy12']]
    k=[]
    for i in range(tam):
        #treino.iloc[:,i] = treino.iloc[:,i].fillna(0.1)################################################################
        #if treino.iloc[:,i].isnull().sum() == 0:
        #X['Future_trend'] = 0
        #X['Future_trend'][-trend_months:] = 1
        #X['Interaction'] = X['Future_trend']*X['Tempo']
        regressor = LinearRegression()
        try:
            y_train = treino.iloc[:,i].fillna(0)#.fillna(treino.iloc[:,i].mean())#
            X['Last'] = y_train.shift(1).rolling(window=move_average, min_periods=1).mean().fillna(method='bfill')
            #X['Last'] = y_train.shift(1).fillna(method='bfill')
            regressor.fit(X, y_train)
        except:
            y_train = treino.iloc[:,i].fillna(0)#.fillna(treino.iloc[:,i].mean())#
            X['Last'] = y_train.shift(1).rolling(window=move_average, min_periods=1).mean().fillna(method='bfill')
            regressor.fit(X, y_train)
        k.append(regressor.coef_[0])
        #if ((abs(get_tvalue(X,y_train))==0) and ((y_train == 0).sum() == 0)):
        if ((abs(regressor.coef_[0])<0) and ((y_train == 0).sum() == 0)):# the value 100 is a trend consideration regulator
            #X.loc[:,'Tempo'] = np.log(X.loc[:,'Tempo'])
            #teste['Last'] = y_train[-1]
            regressor.fit(X, y_train)
            teste['Last'] = y_train[-move_average:].mean()
            #teste.loc[:,'Tempo'] = np.log(teste.loc[:,'Tempo'])
            y_pred = pd.DataFrame(regressor.predict(teste),columns=[colunas[i]+"-R"],index=idx)
            #X.loc[:,'Tempo'] = range(1,treino.shape[0]+1)
            #teste.loc[:,'Tempo'] = range(treino.shape[0]+1,treino.shape[0]+1+30)

            #y_train = treino.iloc[:,i].fillna(0)
            #a = (max(y_train)-min(y_train))
            #y_train_transf=((y_train-min(y_train))/a) + 0.0001
            #y_train = y_train+m+0.1
            #regressor.fit(X, np.log(y_train_transf))
            #y_pred = pd.DataFrame((np.exp(regressor.predict(teste))-0.0001)*a,columns=[colunas[i]+"-R"],index=idx)
        else:
            teste['Last'] = y_train[-3:].mean()
            regressor.fit(X.drop(['Tempo'],axis=1), y_train)
            y_pred = pd.DataFrame(regressor.predict(teste.drop(['Tempo'],axis=1)),columns=[colunas[i]+"-R"],index=idx)
            #regressor.fit(X, np.exp(y_train/100000))
            #y_pred = pd.DataFrame(np.log(regressor.predict(teste))*100000,columns=[colunas[i]+"-R"],index=idx)

            #y_train = treino.iloc[:,i].fillna(0)
            #m=abs(min(y_train))
            #y_train = y_train+m+0.1
            #regressor.fit(X, np.log(y_train))
            #y_pred = pd.DataFrame(np.exp(regressor.predict(teste))-m-0.1,columns=[colunas[i]+"-R"],index=idx)  
        previsao= pd.concat([previsao, y_pred], axis=1, join='outer')
        ultima_coluna=colunas[i]+"-R"
    '''    else:
            #previsao[colunas[i]+"_M"]=treino.iloc[:,i].fillna(0).mean()
            previsao[colunas[i]+"-M"]=pd.DataFrame((pd.concat([treino.iloc[:,i].iloc[9:21], 
                                      treino.iloc[:,i].iloc[9:21],
                                      treino.iloc[:,i].iloc[9:15]],
                                      axis=0, join='outer')).values,columns=[colunas[i]+"-M"],index=idx).fillna(0)
            ultima_coluna=colunas[i]+"-M"'''
    if previsao[ultima_coluna].fillna(0).sum() == 0:
        previsao[ultima_coluna]=treino.iloc[:,i].fillna(0).mean()
    previsao[previsao < 0] = 0
    #previsao.T.to_excel('.\Regression_Results.xlsx')
    #previsao.iloc[3:15].T.sum().sum()
    return previsao
previsao = apply_regression(grupo)
previsao
# Out:
#           B105_BRWTL127_1810-R  B105_BRWTL127_2050-R  B105_BRWTL127_2210-R  \
# Ano  Mês
# 2024 8                7.317011             15.392409             20.430587
#
#           B105_BRWTL150_1810-R  B105_BRWTL150_2050-R  B105_BRWTL150_2160-R  \
# Ano  Mês
# 2024 8                     0.0                   0.0              0.907116
#
#           B105_BRWTL150_2210-R  B105_HPK100_1600-R  B105_HPK100_1700-R  \
# Ano  Mês
# 2024 8                3.705499            11.73723           17.109312
#
#           B105_HPK100_1770-R  ...  B123_HPMFT160_2040-R  B123_HPMFT160_2100-R  \
# Ano  Mês                      ...
# 2024 8              6.613396  ...             66.432788            100.088508
#
#           B123_HPMFT160_2180-R  B123_HPMFT160_2290-R  B123_HPMFT160_2310-R  \
# Ano  Mês
# 2024 8              141.905104            143.124513                   0.0
#
#           B123_HPMFT160_2380-R  B123_HPMFT160_2390-R  B123_HPMFT160_2430-R  \
# Ano  Mês
# 2024 8                     0.0            211.240816          7.771561e-16
#
#           B123_HPMFT160_2440-R  B123_HPMFT160_2490-R
# Ano  Mês
# 2024 8              146.308464            151.575221
#
# [1 rows x 638 columns]

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing
def apply_expsmoothing(grupo,evaluation='yes'):
    expsmoothing=pd.DataFrame()
    treino2=grupo.copy()
    for i in range(grupo.shape[1]):
        treino2.iloc[:,i] = grupo.iloc[:,i].fillna(grupo.iloc[:,i].mean())#################################################################
        if treino2.iloc[:,i].isnull().sum() == 0:
            if evaluation=='yes':
                ###########grupo.iloc[:-1, i]
                train_y2 = treino2.loc[evaluation_initial_month_calibration:evaluation_final_month_calibration,:].iloc[:,i].copy()
                train_y2=train_y2.dropna()
                ##########yearmonth = grupo.index.to_list()[-1]
                tuples = []
                start_year=evaluation_initial_month_validation[0]
                end_year=evaluation_final_month_validation[0]
                start_month=evaluation_initial_month_validation[1]
                end_month=evaluation_final_month_validation[1]
                for year in range(start_year, end_year + 1):
                    start = start_month if year == start_year else 1
                    end = end_month if year == end_year else 12
                    for month in range(start, end + 1):
                        tuples.append((year, month))
                n_forecast = len(tuples)
            else:
                ############train_y = grupo.iloc[:, i]
                train_y2 = treino2.loc[forecast_initial_month_calibration:forecast_final_month_calibration,:].iloc[:,i].copy()
                train_y2=train_y2.dropna()
                ############yearmonth = grupo.index.to_list()[-1]
                ############yearmonth = ((datetime.datetime(yearmonth[0], yearmonth[1], 1) + datetime.timedelta(days=31)).year,
                 ###########(datetime.datetime(yearmonth[0], yearmonth[1], 1) + datetime.timedelta(days=31)).month)
                tuples = []
                start_year=forecast_initial_month_validation[0]
                end_year=forecast_final_month_validation[0]
                start_month=forecast_initial_month_validation[1]
                end_month=forecast_final_month_validation[1]
                for year in range(start_year, end_year + 1):
                    start = start_month if year == start_year else 1
                    end = end_month if year == end_year else 12
                    for month in range(start, end + 1):
                        tuples.append((year, month))
                n_forecast = len(tuples)
            #print(train_y)
            model3 = ExponentialSmoothing(train_y2, trend='add', seasonal='add', damped_trend=True, seasonal_periods=seasonal_periods)
            fit3 = model3.fit()
            ident = pd.MultiIndex.from_tuples(tuples,##################[yearmonth], 
                                              names=["Ano", "Mês"])
            try:
                k3 = fit3.predict(start=0, end=23+n_forecast)###################1)
                if evaluation=='yes':
                    prediction=k3.iloc[-1]
                else:
                    prediction=k3.iloc[-24:]
            except ValueError:
                k3=0
                print('OBSERVE ESTA SÉRIE !!!!!!!!!!!!!!!!!')
                pass
            if evaluation=='yes':
                inte_=pd.DataFrame({colunas[i]+"-R": prediction},index=ident)
            else:
                inte_=pd.DataFrame({colunas[i]+"-R": prediction.to_list()},index=ident)
            expsmoothing= pd.concat([expsmoothing, inte_], axis=1, join='outer')
            
            ultima_coluna=colunas[i]+"-R"
        else:
            expsmoothing[colunas[i]+"-M"]=grupo.iloc[:,i].fillna(0).mean()
            ultima_coluna=colunas[i]+"-M"
        #if expsmoothing[ultima_coluna].fillna(0).sum() == 0:
        #    expsmoothing[ultima_coluna]=grupo.iloc[:,i].fillna(0).mean()
    expsmoothing[expsmoothing < 0] = 0
    
    return expsmoothing
expsmoothing = apply_expsmoothing(grupo)
expsmoothing
# Out:
#           B105_BRWTL127_1810-R  B105_BRWTL127_2050-R  B105_BRWTL127_2210-R  \
# Ano  Mês
# 2024 8                4.774124             10.583738              5.183529
#
#           B105_BRWTL150_1810-R  B105_BRWTL150_2050-R  B105_BRWTL150_2160-R  \
# Ano  Mês
# 2024 8                3.865459                   0.0              0.748826
#
#           B105_BRWTL150_2210-R  B105_HPK100_1600-R  B105_HPK100_1700-R  \
# Ano  Mês
# 2024 8                8.674352           10.675173            8.615979
#
#           B105_HPK100_1770-R  ...  B123_HPMFT160_2040-R  B123_HPMFT160_2100-R  \
# Ano  Mês                      ...
# 2024 8              9.071303  ...             86.620643            180.770045
#
#           B123_HPMFT160_2180-R  B123_HPMFT160_2290-R  B123_HPMFT160_2310-R  \
# Ano  Mês
# 2024 8              190.879774            138.902377               4.14874
#
#           B123_HPMFT160_2380-R  B123_HPMFT160_2390-R  B123_HPMFT160_2430-R  \
# Ano  Mês
# 2024 8                    1.89            327.064945                  7.55
#
#           B123_HPMFT160_2440-R  B123_HPMFT160_2490-R
# Ano  Mês
# 2024 8              187.554103            142.747852
#
# [1 rows x 638 columns]

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

def apply_seasonaldecompose(grupo, evaluation='yes'):
    decompose = pd.DataFrame()
    treino = grupo.copy()
    for i in range(grupo.shape[1]):
        treino.iloc[:,i] = grupo.iloc[:,i].fillna(grupo.iloc[:,i].mean())
        if treino.iloc[:,i].isnull().sum() == 0:
            if evaluation=='yes':
                train_y = treino.iloc[:,i].copy()
                tuples = [(evaluation_initial_month_validation[0], evaluation_initial_month_validation[1])]
                n_forecast = len(tuples)
                index = pd.date_range(start=datetime(*(evaluation_initial_month_calibration+(1,))).date()
                                  , periods=train_y.shape[0], freq='MS')
            else:
                train_y = treino.iloc[:,i].copy()
                start_year = forecast_initial_month_validation[0]
                end_year = forecast_final_month_validation[0]
                start_month = forecast_initial_month_validation[1]
                end_month = forecast_final_month_validation[1]
                tuples = []
                for year in range(start_year, end_year + 1):
                    start = start_month if year == start_year else 1
                    end = end_month if year == end_year else 12
                    for month in range(start, end + 1):
                        tuples.append((year, month))
                n_forecast = len(tuples)
                index = pd.date_range(start=datetime(*(forecast_initial_month_calibration+(1,))).date()
                                  , periods=train_y.shape[0], freq='MS')
            try:
                result = seasonal_decompose(pd.DataFrame(train_y.values,index=index), model='add')
                seasonal = result.seasonal.fillna(method='ffill')
                trend = result.trend.fillna(method='ffill')
                residual = result.resid.fillna(method='ffill')
                forecasted_values = []
                for n in range(n_forecast): 
                    k = trend[-1] + seasonal[(seasonal.index[-1].month + n - 1) % 12] + np.sum(residual[-12:]) / 12 
                    forecasted_values.append(k)
                ident = pd.MultiIndex.from_tuples(tuples, names=["Ano", "Mês"])
                inte=pd.DataFrame(forecasted_values,columns=[treino.columns[i]+"-R"], index=ident)
                decompose = pd.concat([decompose, inte], axis=1, join='outer')
            except ValueError as ve:
                print(f'Error with column {i}: {ve}')
    decompose[decompose < 0] = 0
    return decompose

decompose = apply_seasonaldecompose(grupo)
decompose
# Out:
# Error with column 0: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 1: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 2: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 3: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 4: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 5: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 6: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 7: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 8: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 9: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 10: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 11: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 12: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 13: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 14: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 15: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 16: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 17: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 18: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 19: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 20: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 21: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 22: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 23: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 24: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 25: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 26: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 27: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 28: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 29: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 30: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 31: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 32: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 33: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 34: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 35: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 36: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 37: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 38: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 39: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 40: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 41: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 42: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 43: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 44: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 45: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 46: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 47: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 48: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 49: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 50: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 51: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 52: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 53: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 54: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 55: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 56: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 57: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 58: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 59: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 60: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 61: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 62: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 63: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 64: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 65: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 66: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 67: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 68: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 69: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 70: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 71: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 72: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 73: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 74: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 75: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 76: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 77: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 78: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 79: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 80: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 81: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 82: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 83: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 84: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 85: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 86: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 87: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 88: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 89: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 90: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 91: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 92: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 93: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 94: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 95: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 96: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 97: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 98: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 99: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 100: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 101: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 102: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 103: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 104: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 105: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 106: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 107: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 108: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 109: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 110: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 111: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 112: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 113: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 114: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 115: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 116: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 117: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 118: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 119: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 120: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 121: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 122: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 123: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 124: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 125: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 126: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 127: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 128: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 129: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 130: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 131: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 132: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 133: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 134: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 135: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 136: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 137: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 138: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 139: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 140: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 141: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 142: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 143: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 144: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 145: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 146: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 147: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 148: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 149: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 150: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 151: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 152: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 153: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 154: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 155: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 156: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 157: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 158: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 159: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 160: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 161: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 162: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 163: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 164: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 165: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 166: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 167: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 168: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 169: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 170: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 171: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 172: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 173: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 174: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 175: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 176: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 177: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 178: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 179: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 180: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 181: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 182: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 183: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 184: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 185: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 186: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 187: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 188: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 189: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 190: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 191: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 192: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 193: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 194: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 195: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 196: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 197: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 198: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 199: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 200: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 201: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 202: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 203: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 204: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 205: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 206: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 207: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 208: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 209: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 210: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 211: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 212: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 213: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 214: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 215: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 216: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 217: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 218: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 219: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 220: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 221: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 222: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 223: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 224: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 225: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 226: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 227: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 228: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 229: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 230: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 231: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 232: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 233: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 234: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 235: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 236: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 237: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 238: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 239: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 240: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 241: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 242: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 243: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 244: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 245: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 246: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 247: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 248: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 249: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 250: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 251: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 252: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 253: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 254: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 255: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 256: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 257: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 258: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 259: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 260: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 261: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 262: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 263: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 264: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 265: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 266: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 267: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 268: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 269: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 270: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 271: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 272: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 273: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 274: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 275: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 276: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 277: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 278: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 279: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 280: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 281: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 282: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 283: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 284: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 285: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 286: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 287: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 288: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 289: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 290: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 291: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 292: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 293: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 294: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 295: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 296: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 297: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 298: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 299: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 300: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 301: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 302: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 303: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 304: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 305: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 306: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 307: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 308: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 309: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 310: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 311: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 312: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 313: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 314: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 315: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 316: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 317: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 318: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 319: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 320: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 321: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 322: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 323: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 324: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 325: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 326: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 327: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 328: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 329: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 330: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 331: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 332: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 333: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 334: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 335: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 336: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 337: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 338: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 339: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 340: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 341: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 342: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 343: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 344: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 345: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 346: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 347: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 348: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 349: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 350: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 351: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 352: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 353: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 354: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 355: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 356: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 357: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 358: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 359: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 360: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 361: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 362: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 363: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 364: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 365: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 366: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 367: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 368: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 369: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 370: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 371: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 372: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 373: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 374: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 375: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 376: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 377: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 378: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 379: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 380: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 381: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 382: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 383: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 384: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 385: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 386: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 387: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 388: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 389: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 390: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 391: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 392: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 393: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 394: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 395: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 396: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 397: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 398: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 399: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 400: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 401: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 402: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 403: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 404: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 405: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 406: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 407: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 408: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 409: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 410: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 411: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 412: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 413: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 414: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 415: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 416: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 417: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 418: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 419: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 420: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 421: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 422: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 423: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 424: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 425: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 426: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 427: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 428: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 429: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 430: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 431: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 432: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 433: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 434: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 435: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 436: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 437: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 438: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 439: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 440: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 441: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 442: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 443: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 444: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# ...
# Error with column 491: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 492: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 493: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 494: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 495: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 496: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 497: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 498: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 499: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 500: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 501: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 502: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 503: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 504: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 505: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 506: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 507: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 508: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 509: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 510: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 511: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 512: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 513: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 514: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 515: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 516: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 517: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 518: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 519: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 520: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 521: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 522: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 523: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 524: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 525: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 526: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 527: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 528: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 529: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 530: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 531: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 532: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 533: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 534: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 535: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 536: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 537: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 538: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 539: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 540: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 541: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 542: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 543: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 544: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 545: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 546: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 547: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 548: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 549: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 550: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 551: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 552: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 553: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 554: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 555: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 556: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 557: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 558: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 559: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 560: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 561: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 562: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 563: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 564: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 565: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 566: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 567: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 568: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 569: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 570: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 571: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 572: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 573: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 574: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 575: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 576: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 577: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 578: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 579: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 580: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 581: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 582: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 583: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 584: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 585: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 586: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 587: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 588: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 589: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 590: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 591: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 592: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 593: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 594: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 595: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 596: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 597: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 598: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 599: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 600: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 601: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 602: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 603: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 604: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 605: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 606: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 607: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 608: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 609: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 610: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 611: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 612: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 613: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 614: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 615: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 616: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 617: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 618: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 619: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 620: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 621: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 622: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 623: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 624: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 625: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 626: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 627: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 628: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 629: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 630: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 631: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 632: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 633: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 634: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 635: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 636: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Error with column 637: x must have 2 complete cycles requires 24 observations. x only has 21 observation(s)
# Empty DataFrame
# Columns: []
# Index: []

# %%
# from statsmodels.tsa.seasonal import seasonal_decompose
# def apply_seasonaldecompose(grupo,evaluation='yes'):
#     decompose=pd.DataFrame()
#     treino=grupo.copy()
#     for i in range(grupo.shape[1]):
#         treino.iloc[:,i] = grupo.iloc[:,i].fillna(grupo.iloc[:,i].mean())#################################################################
#         if treino.iloc[:,i].isnull().sum() == 0:
#             if evaluation=='yes':
#                 ###########grupo.iloc[:-1, i]
#                 train_y = treino.loc[evaluation_initial_month_calibration:evaluation_final_month_calibration,:].iloc[:,i].copy()
#                 train_y=train_y.dropna()
#                 ##########yearmonth = grupo.index.to_list()[-1]
#                 tuples = []
#                 start_year=evaluation_initial_month_validation[0]
#                 end_year=evaluation_final_month_validation[0]
#                 start_month=evaluation_initial_month_validation[1]
#                 end_month=evaluation_final_month_validation[1]
#                 for year in range(start_year, end_year + 1):
#                     start = start_month if year == start_year else 1
#                     end = end_month if year == end_year else 12
#                     for month in range(start, end + 1):
#                         tuples.append((year, month))
#                 n_forecast = len(tuples)
#                 index = pd.date_range(start=datetime(*(evaluation_initial_month_calibration+(1,))).date()
#                                   , end=datetime(*(evaluation_final_month_calibration+(1,))).date(), freq='MS')

#             else:
#                 ############train_y = grupo.iloc[:, i]
#                 train_y = treino.loc[forecast_initial_month_calibration:forecast_final_month_calibration,:].iloc[:,i].copy()
#                 train_y=train_y.dropna()
#                 ############yearmonth = grupo.index.to_list()[-1]
#                 ############yearmonth = ((datetime.datetime(yearmonth[0], yearmonth[1], 1) + datetime.timedelta(days=31)).year,
#                  ###########(datetime.datetime(yearmonth[0], yearmonth[1], 1) + datetime.timedelta(days=31)).month)
#                 tuples = []
#                 start_year=forecast_initial_month_validation[0]
#                 end_year=forecast_final_month_validation[0]
#                 start_month=forecast_initial_month_validation[1]
#                 end_month=forecast_final_month_validation[1]
#                 for year in range(start_year, end_year + 1):
#                     start = start_month if year == start_year else 1
#                     end = end_month if year == end_year else 12
#                     for month in range(start, end + 1):
#                         tuples.append((year, month))
#                 n_forecast = len(tuples)
            
#                 index = pd.date_range(start=datetime(*(evaluation_initial_month_calibration+(1,))).date()
#                                   , end=datetime(*(evaluation_final_month_calibration+(1,))).date(), freq='MS')
#             #print(pd.DataFrame(train_y.values,index=index))
#             result = seasonal_decompose(pd.DataFrame(train_y.values,index=index), model='add')
#             ident = pd.MultiIndex.from_tuples(tuples,##################[yearmonth], 
#                                               names=["Ano", "Mês"])
#             try:
#                 seasonal = result.seasonal
#                 trend = result.trend
#                 residual = result.resid
#                 n_periods = 1
#                 trend.fillna(trend.mean(),inplace=True)
#                 residual.fillna(residual.mean(),inplace=True)
#                 k = trend[-1] + seasonal[-1] + np.sum(residual[-12:]) / 12 # forecast for the next period
#             except ValueError:
#                 k=0
#                 print('OBSERVE ESTA SÉRIE !!!!!!!!!!!!!!!!!')
#                 pass
#             if evaluation=='yes':
#                 inte3=pd.DataFrame({colunas[i]+"-R": prediction2},index=ident)
#             else:
#                 inte3=pd.DataFrame({colunas[i]+"-R": prediction2.to_list()},index=ident)
#             #inte3=pd.DataFrame(k,columns=[colunas[i]+"-R"],index=ident)
#             decompose= pd.concat([decompose, inte3], axis=1, join='outer')
#             ultima_coluna=colunas[i]+"-R"
#         else:
#             decompose[colunas[i]+"-M"]=grupo.iloc[:,i].fillna(0).mean()
#             ultima_coluna=colunas[i]+"-M"
#         if decompose[ultima_coluna].fillna(0).sum() == 0:
#             decompose[ultima_coluna]=grupo.iloc[:,i].fillna(0).mean()
#     decompose[decompose < 0] = 0
#     return decompose
# #decompose = apply_seasonaldecompose(grupo)
# decompose = apply_seasonaldecompose(grupo)
# decompose

# %%
sarimas=pd.DataFrame([sarimas],columns=grupo.columns,#.to_list(),
                     index=pd.MultiIndex.from_tuples([evaluation_initial_month_validation], names=['Ano', 'Mês']))
df_melted = pd.melt(grupo, value_vars=grupo.columns,ignore_index=False).reset_index().fillna(0)
previsao = pd.melt(previsao, value_vars=previsao.columns,ignore_index=False)
previsao['Chave'] = previsao['variable'].str[:-2]
previsao.reset_index(inplace=True)
previsao2=previsao.merge(df_melted, left_on=['Ano','Mês','Chave'],
                        right_on=['Ano','Mês','Chave'],
                        how='left')
previsao2.drop(['Chave'],axis=1,inplace=True)
previsao2 = previsao2.rename(columns={'value_x': 'Forecast', 'value_y': 'Actual'})
previsao2.loc[:,'MAD'] = abs(previsao2.loc[:,'Forecast']-previsao2.loc[:,'Actual'])
previsao2 = previsao2.set_index(['Ano','Mês'])
k=df_melted.loc[~((df_melted['Ano']==grupo.index.to_list()[-1][0]) & (df_melted['Mês']>=grupo.index.to_list()[-1][1]))]
k=k.groupby('Chave').value.agg(['mean']).reset_index()
previsao2['Chave'] = previsao2['variable'].str[:-2]
previsao3=previsao2.reset_index().merge(k, left_on=['Chave'],
                        right_on=['Chave'],
                        how='left')
previsao3.loc[:,'MAD_mean'] = abs(previsao3.loc[:,'mean']-previsao3.loc[:,'Actual'])
sarimas = pd.melt(sarimas, value_vars=sarimas.columns,ignore_index=False)


#sarimas['Chave'] = sarimas['variable'].str[:-2]
sarimas.reset_index(inplace=True)
sarimas.rename(columns={'value': 'Forecast_Sarima'},inplace=True)#,'Chave': 'variable_Sarima'},inplace=True)
previsao4 = previsao3.merge(sarimas, left_on=['Ano','Mês','Chave'],
                        right_on=['Ano','Mês','Chave'],
                        how='left')
previsao4.loc[:,'MAD_Sarima'] = abs(previsao4.loc[:,'Forecast_Sarima']-previsao4.loc[:,'Actual'])
expsmoothing = pd.melt(expsmoothing, value_vars=expsmoothing.columns,ignore_index=False)
expsmoothing['Chave'] = expsmoothing['variable'].str[:-2]
expsmoothing.reset_index(inplace=True)
expsmoothing.rename(columns={'value': 'Forecast_ExpSmooth','variable': 'variable_ExpSmooth'},inplace=True)
previsao5 = previsao4.merge(expsmoothing, left_on=['Ano','Mês','Chave'],
                        right_on=['Ano','Mês','Chave'],
                        how='left')
previsao5.loc[:,'MAD_ExpSmooth'] = abs(previsao5.loc[:,'Forecast_ExpSmooth']-previsao5.loc[:,'Actual'])
# decompose = pd.melt(decompose, value_vars=decompose.columns,ignore_index=False)
# decompose['Chave'] = decompose['variable'].str[:-2]
# decompose.reset_index(inplace=True)
# decompose.rename(columns={'value': 'Forecast_Decompose','variable': 'variable_Decompose'},inplace=True)
# previsao6 = previsao5.merge(decompose, left_on=['Ano','Mês','Chave'],
#                         right_on=['Ano','Mês','Chave'],
#                         how='left')
# previsao6.loc[:,'MAD_Decompose'] = abs(previsao6.loc[:,'Forecast_Decompose']-previsao6.loc[:,'Actual'])
somas=previsao5.loc[:,['Chave','MAD','MAD_mean','MAD_Sarima','MAD_ExpSmooth']].groupby('Chave').agg(['sum']).reset_index()
somas['Menor']=somas.iloc[:,1:5].idxmin(axis=1)
somas=somas.sort_values('Chave')
previsao6=previsao5.sort_values('Chave')
condicoes = [somas['Menor'] == ('MAD', 'sum'),
    somas['Menor'] == ('MAD_mean', 'sum'),
    somas['Menor'] == ('MAD_Sarima', 'sum'),
    somas['Menor'] == ('MAD_ExpSmooth', 'sum')]
    # somas['Menor'] == ('MAD_Decompose', 'sum')]
valores = [previsao5['Forecast'], previsao5['mean'], previsao5['Forecast_Sarima'],previsao5['Forecast_ExpSmooth']]
previsao5['Forecast_Mixed']= np.select(condicoes, valores)
previsao5.loc[:,'MAD_Mixed'] = abs(previsao5.loc[:,'Forecast_Mixed']-previsao5.loc[:,'Actual'])
forecast_mixed=previsao5.pivot_table(values='Forecast_Mixed', index=['Chave'],
                     columns=['Ano','Mês'],
                     aggfunc=sum,margins=False)

previsao5['variable'] = previsao5['variable'].map(lambda x: x[:-2])
previsao5[Key] = previsao5['variable'].str.split('_', expand=True)
previsao5.drop(['variable','variable_ExpSmooth'],axis=1,inplace=True)
previsao5=previsao5[k.columns.tolist()[:2]+previsao5.columns.tolist()[-3:]+previsao5.columns.tolist()[2:-3]]
previsao5['melhor'] = somas['Menor']
previsao5.to_excel('ActualAndForecast_forecaster.xlsx',index=False)
previsao5
# Out:
#                   Chave      mean Centro        TG FormatoNew      Forecast  \
# 0    B105_BRWTL127_1810    0.8775   B105  BRWTL127       1810  7.317011e+00
# 1    B105_BRWTL127_2050    2.3150   B105  BRWTL127       2050  1.539241e+01
# 2    B105_BRWTL127_2210    2.2435   B105  BRWTL127       2210  2.043059e+01
# 3    B105_BRWTL150_1810    2.6995   B105  BRWTL150       1810  0.000000e+00
# 4    B105_BRWTL150_2050   18.9325   B105  BRWTL150       2050  0.000000e+00
# ..                  ...       ...    ...       ...        ...           ...
# 633  B123_HPMFT160_2380    0.0945   B123  HPMFT160       2380  0.000000e+00
# 634  B123_HPMFT160_2390  275.3335   B123  HPMFT160       2390  2.112408e+02
# 635  B123_HPMFT160_2430    0.3775   B123  HPMFT160       2430  7.771561e-16
# 636  B123_HPMFT160_2440  161.0360   B123  HPMFT160       2440  1.463085e+02
# 637  B123_HPMFT160_2490  165.1665   B123  HPMFT160       2490  1.515752e+02
#
#      Actual           MAD               Chave      mean  MAD_mean  \
# 0      0.31  7.007011e+00  B105_BRWTL127_1810    0.8775    0.5675
# 1      3.70  1.169241e+01  B105_BRWTL127_2050    2.3150    1.3850
# 2      9.67  1.076059e+01  B105_BRWTL127_2210    2.2435    7.4265
# 3      0.00  0.000000e+00  B105_BRWTL150_1810    2.6995    2.6995
# 4      0.00  0.000000e+00  B105_BRWTL150_2050   18.9325   18.9325
# ..      ...           ...                 ...       ...       ...
# 633    0.00  0.000000e+00  B123_HPMFT160_2380    0.0945    0.0945
# 634  113.86  9.738082e+01  B123_HPMFT160_2390  275.3335  161.4735
# 635    0.00  7.771561e-16  B123_HPMFT160_2430    0.3775    0.3775
# 636   59.28  8.702846e+01  B123_HPMFT160_2440  161.0360  101.7560
# 637   42.93  1.086452e+02  B123_HPMFT160_2490  165.1665  122.2365
#
#      Forecast_Sarima  MAD_Sarima  Forecast_ExpSmooth  MAD_ExpSmooth  \
# 0           0.850476    0.540476            4.774124       4.464124
# 1           2.380952    1.319048           10.583738       6.883738
# 2           2.597143    7.072857            5.183529       4.486471
# 3           2.570952    2.570952            3.865459       3.865459
# 4          18.030952   18.030952            0.000000       0.000000
# ..               ...         ...                 ...            ...
# 633         0.090000    0.090000            1.890000       1.890000
# 634       267.644286  153.784286          327.064945     213.204945
# 635         0.359524    0.359524            7.550000       7.550000
# 636       156.190476   96.910476          187.554103     128.274103
# 637       159.345714  116.415714          142.747852      99.817852
#
#      Forecast_Mixed     MAD_Mixed                melhor
# 0      8.504762e-01  5.404762e-01     (MAD_Sarima, sum)
# 1      2.380952e+00  1.319048e+00     (MAD_Sarima, sum)
# 2      5.183529e+00  4.486471e+00  (MAD_ExpSmooth, sum)
# 3      0.000000e+00  0.000000e+00            (MAD, sum)
# 4      0.000000e+00  0.000000e+00            (MAD, sum)
# ..              ...           ...                   ...
# 633    0.000000e+00  0.000000e+00            (MAD, sum)
# 634    2.112408e+02  9.738082e+01            (MAD, sum)
# 635    7.771561e-16  7.771561e-16            (MAD, sum)
# 636    1.463085e+02  8.702846e+01            (MAD, sum)
# 637    1.427479e+02  9.981785e+01  (MAD_ExpSmooth, sum)
#
# [638 rows x 18 columns]

# %%
sarimas
# Out:
#       Ano  Mês               Chave  Forecast_Sarima
# 0    2024    8  B105_BRWTL127_1810         0.850476
# 1    2024    8  B105_BRWTL127_2050         2.380952
# 2    2024    8  B105_BRWTL127_2210         2.597143
# 3    2024    8  B105_BRWTL150_1810         2.570952
# 4    2024    8  B105_BRWTL150_2050        18.030952
# ..    ...  ...                 ...              ...
# 633  2024    8  B123_HPMFT160_2380         0.090000
# 634  2024    8  B123_HPMFT160_2390       267.644286
# 635  2024    8  B123_HPMFT160_2430         0.359524
# 636  2024    8  B123_HPMFT160_2440       156.190476
# 637  2024    8  B123_HPMFT160_2490       159.345714
#
# [638 rows x 4 columns]

# %%
print('Regression WAPE = ',np.round((previsao5.MAD.sum()/previsao5.Actual.sum())*100,0),'%',sep='')
print('Mean WAPE = ',np.round((previsao5.MAD_mean.sum()/previsao5.Actual.sum())*100,0),'%',sep='')
print('Sarima WAPE = ',np.round((previsao5.MAD_Sarima.sum()/previsao5.Actual.sum())*100,0),'%',sep='')
print('ExpSmoothing WAPE = ',np.round((previsao5.MAD_ExpSmooth.sum()/previsao5.Actual.sum())*100,0),'%',sep='')
# print('Decompose WAPE = ',np.round((previsao5.MAD_Decompose.sum()/previsao5.Actual.sum())*100,0),'%',sep='')
print('Mixed WAPE = ',np.round((previsao5.MAD_Mixed.sum()/previsao5.Actual.sum())*100,0),'%',sep='')
# Out:
# Regression WAPE = 175.0%
# Mean WAPE = 160.0%
# Sarima WAPE = 153.0%
# ExpSmoothing WAPE = 209.0%
# Mixed WAPE = 120.0%

# %%
sarimas = apply_sarima(grupo,evaluation='no')
expsmoothing = apply_expsmoothing(grupo,evaluation='no')
# decompose = apply_seasonaldecompose(grupo,evaluation='no')
previsao = apply_regression(grupo,evaluation='no')
df_melted = pd.melt(grupo, value_vars=grupo.columns,ignore_index=False).reset_index()
k=df_melted.loc[~((df_melted['Ano']==grupo.index.to_list()[-1][0]) & (df_melted['Mês']>=grupo.index.to_list()[-1][1]))]#.fillna(0)
k=k.groupby('Chave').value.agg(['mean']).reset_index()
# Função para renomear colunas
def rename_columns(row, columns):
    new_columns = {}
    for i, column in enumerate(columns):
        new_columns[column] = row[i]
    return new_columns

# Renomear colunas
k = k.T.rename(columns=rename_columns(k.T.iloc[0], k.T.columns)).iloc[1:,:]
k=k.T

dates = pd.date_range(start=f"{forecast_initial_month_validation[0]}-{forecast_initial_month_validation[1]}", 
                      end=f"{forecast_final_month_validation[0]}-{forecast_final_month_validation[1]}", 
                      freq='MS')
sarimas = pd.DataFrame(sarimas.reshape(-1, len(dates)), columns=[f"Sarima_({date.year}, {date.month})" for date in dates])
sarimas.index=grupo.columns.to_list()
k=k.merge(sarimas,left_index=True, right_index=True, how='outer')

previsao=previsao.T
previsao.index = previsao.index.map(lambda x: x[:-2])
previsao.columns = previsao.columns.map(lambda x: 'Regression_{}'.format(x))
k=k.merge(previsao,left_index=True, right_index=True, how='outer')

expsmoothing=expsmoothing.T
expsmoothing.index = expsmoothing.index.map(lambda x: x[:-2])
expsmoothing.columns = expsmoothing.columns.map(lambda x: 'ExpSmoothing_{}'.format(x))
k=k.merge(expsmoothing,left_index=True, right_index=True, how='outer')

# decompose=decompose.T
# decompose.index = decompose.index.map(lambda x: x[:-2])
# decompose.columns = decompose.columns.map(lambda x: 'Decompose_{}'.format(x))
# k=k.merge(decompose,left_index=True, right_index=True, how='outer')

# %%
sarimas
# Out:
#                     Sarima_(2024, 9)  Sarima_(2024, 10)  Sarima_(2024, 11)  \
# B105_BRWTL127_1810          0.850476           2.380952           2.597143
# B105_BRWTL127_2050         92.433810           0.393333           0.057619
# B105_BRWTL127_2210         10.307143          14.035714           0.335238
# B105_BRWTL150_1810          2.476667           0.908571           0.953333
# B105_BRWTL150_2050          1.342381           1.324762           0.041905
# ...                              ...                ...                ...
# B123_HPMFT160_2380          0.000000           0.000000           0.000000
# B123_HPMFT160_2390        296.074588         285.817322         280.846406
# B123_HPMFT160_2430          0.000000           0.000000           0.000000
# B123_HPMFT160_2440        142.643544         161.129934         161.129934
# B123_HPMFT160_2490        151.169293         162.466708         162.466708
#
#                     Sarima_(2024, 12)  Sarima_(2025, 1)  Sarima_(2025, 2)  \
# B105_BRWTL127_1810           2.570952         18.030952          0.140952
# B105_BRWTL127_2050          61.837143         11.676190          1.249524
# B105_BRWTL127_2210          17.649524         33.433810         50.559524
# B105_BRWTL150_1810           8.799524          2.429524          1.387143
# B105_BRWTL150_2050           7.344286         29.190000          0.002381
# ...                               ...               ...               ...
# B123_HPMFT160_2380           0.000000          0.000000          0.000000
# B123_HPMFT160_2390         278.437380        277.269909        276.704124
# B123_HPMFT160_2430           0.000000          0.000000          0.000000
# B123_HPMFT160_2440         161.129934        161.129934        161.129934
# B123_HPMFT160_2490         162.466708        162.466708        162.466708
#
#                     Sarima_(2025, 3)  Sarima_(2025, 4)  Sarima_(2025, 5)  \
# B105_BRWTL127_1810          6.500952         15.304762         23.026190
# B105_BRWTL127_2050        133.738571         82.209048        138.571905
# B105_BRWTL127_2210         63.903810          1.261429          1.985238
# B105_BRWTL150_1810         16.562381          0.370000          7.945714
# B105_BRWTL150_2050         46.186190        215.577143         94.435714
# ...                              ...               ...               ...
# B123_HPMFT160_2380          0.000000          0.000000          0.000000
# B123_HPMFT160_2390        276.429931        276.297051        276.232654
# B123_HPMFT160_2430          0.000000          0.000000          0.000000
# B123_HPMFT160_2440        161.129934        161.129934        161.129934
# B123_HPMFT160_2490        162.466708        162.466708        162.466708
#
#                     Sarima_(2025, 6)  ...  Sarima_(2025, 11)  \
# B105_BRWTL127_1810          8.003333  ...          65.220952
# B105_BRWTL127_2050          1.888571  ...         132.021429
# B105_BRWTL127_2210         51.492857  ...         157.721905
# B105_BRWTL150_1810          1.512381  ...          12.924286
# B105_BRWTL150_2050         71.586667  ...         107.063333
# ...                              ...  ...                ...
# B123_HPMFT160_2380          0.000000  ...           0.000000
# B123_HPMFT160_2390        276.201446  ...         276.172884
# B123_HPMFT160_2430          0.000000  ...           0.000000
# B123_HPMFT160_2440        161.129934  ...         161.129934
# B123_HPMFT160_2490        162.466708  ...         162.466708
#
#                     Sarima_(2025, 12)  Sarima_(2026, 1)  Sarima_(2026, 2)  \
# B105_BRWTL127_1810           0.770476         25.859524          5.386667
# B105_BRWTL127_2050           1.093333          3.957619        176.160476
# B105_BRWTL127_2210           0.319524        140.363810          0.203333
# B105_BRWTL150_1810          24.490952         22.273333          0.392381
# B105_BRWTL150_2050           2.959048         81.244762          0.436667
# ...                               ...               ...               ...
# B123_HPMFT160_2380           0.000000          0.000000          0.000000
# B123_HPMFT160_2390         276.172480        276.172284        276.172189
# B123_HPMFT160_2430           0.000000          0.000000          0.000000
# B123_HPMFT160_2440         161.129934        161.129934        161.129934
# B123_HPMFT160_2490         162.466708        162.466708        162.466708
#
#                     Sarima_(2026, 3)  Sarima_(2026, 4)  Sarima_(2026, 5)  \
# B105_BRWTL127_1810         16.308571          9.683810         27.748571
# B105_BRWTL127_2050          0.192381         10.970952          1.177619
# B105_BRWTL127_2210         87.227143        180.958095         50.438571
# B105_BRWTL150_1810         17.771905         39.526667         21.392381
# B105_BRWTL150_2050         90.968095          3.107619         30.497143
# ...                              ...               ...               ...
# B123_HPMFT160_2380          0.000000          0.000000          0.000000
# B123_HPMFT160_2390        276.172143        276.172121        276.172110
# B123_HPMFT160_2430          0.000000          0.000000          0.000000
# B123_HPMFT160_2440        161.129934        161.129934        161.129934
# B123_HPMFT160_2490        162.466708        162.466708        162.466708
#
#                     Sarima_(2026, 6)  Sarima_(2026, 7)  Sarima_(2026, 8)
# B105_BRWTL127_1810          0.450952          9.590476         43.365714
# B105_BRWTL127_2050          0.034286         14.757143          0.319048
# B105_BRWTL127_2210          0.995714        283.827143          0.134286
# B105_BRWTL150_1810         32.220476          0.009524          2.414286
# B105_BRWTL150_2050          7.910476         26.482857         11.093333
# ...                              ...               ...               ...
# B123_HPMFT160_2380          0.000000          0.000000          0.000000
# B123_HPMFT160_2390        276.172104        276.172102        276.172101
# B123_HPMFT160_2430          0.000000          0.000000          0.000000
# B123_HPMFT160_2440        161.129934        161.129934        161.129934
# B123_HPMFT160_2490        162.466708        162.466708        162.466708
#
# [638 rows x 24 columns]

# %%
backup = k

# %%
k = backup

# %%
k = backup
k=k.reset_index()
#k['Melhor'] = somas["Menor"]
k[Key] = k['index'].str.split('_', expand=True)
k.drop(['index'],axis=1,inplace=True)
k=k[k.columns.tolist()[-3:]+k.columns.tolist()[:-3]]
k
tuples = []
start_year=forecast_initial_month_validation[0]
end_year=forecast_final_month_validation[0]
start_month=forecast_initial_month_validation[1]
end_month=forecast_final_month_validation[1]
for year in range(start_year, end_year + 1):
    start = start_month if year == start_year else 1
    end = end_month if year == end_year else 12
    for month in range(start, end + 1):
        tuples.append((year, month))
n_forecast = len(tuples)
k['Best_model']=somas['Menor'].apply(lambda x: x[0]) 
condicoes = [k['Best_model'] == 'MAD',
    k['Best_model'] == 'MAD_mean',
    k['Best_model'] == 'MAD_Sarima',
    k['Best_model'] == 'MAD_ExpSmooth']
    # k['Best_model'] == 'MAD_Decompose']
valores = ['Regression','Mean','Sarima','ExpSmooth']#,'Decompose']
k['Best_model']= np.select(condicoes, valores)
for i in range(n_forecast):
    condicoes = [k['Best_model'] == 'Regression',
    k['Best_model'] == 'Mean',
    k['Best_model'] == 'Sarima',
    k['Best_model'] == 'ExpSmooth']
    # k['Best_model'] == 'Decompose']
    valores=[k['Regression_'+str(tuples[i])],k['mean'],
                                       k['Sarima_'+str(tuples[i])],k['ExpSmoothing_'+str(tuples[i])]]#,
                                    #    k['Decompose_'+str(tuples[i])]]
    k.loc[:,'Mixed_'+str(tuples[i])] = np.select(condicoes, valores)
k[Key + ['Best_model'] + k.columns[k.columns.str.startswith('Mixed_')].to_list()].to_excel('forecast_all_models_forecaster.xlsx',index=False)
k
# Out:
#     Centro        TG FormatoNew      mean  Sarima_(2024, 9)  \
# 0     B105  BRWTL127       1810    4.3875          0.850476
# 1     B105  BRWTL127       2050      9.26         92.433810
# 2     B105  BRWTL127       2210   11.2175         10.307143
# 3     B105  BRWTL150       1810  3.856429          2.476667
# 4     B105  BRWTL150       2050   18.9325          1.342381
# ..     ...       ...        ...       ...               ...
# 633   B123  HPMFT160       2380      1.89          0.000000
# 634   B123  HPMFT160       2390  275.3335        296.074588
# 635   B123  HPMFT160       2430      7.55          0.000000
# 636   B123  HPMFT160       2440   161.036        142.643544
# 637   B123  HPMFT160       2490  165.1665        151.169293
#
#      Sarima_(2024, 10)  Sarima_(2024, 11)  Sarima_(2024, 12)  \
# 0             2.380952           2.597143           2.570952
# 1             0.393333           0.057619          61.837143
# 2            14.035714           0.335238          17.649524
# 3             0.908571           0.953333           8.799524
# 4             1.324762           0.041905           7.344286
# ..                 ...                ...                ...
# 633           0.000000           0.000000           0.000000
# 634         285.817322         280.846406         278.437380
# 635           0.000000           0.000000           0.000000
# 636         161.129934         161.129934         161.129934
# 637         162.466708         162.466708         162.466708
#
#      Sarima_(2025, 1)  Sarima_(2025, 2)  ...  Mixed_(2025, 11)  \
# 0           18.030952          0.140952  ...         65.220952
# 1           11.676190          1.249524  ...        132.021429
# 2           33.433810         50.559524  ...         20.351594
# 3            2.429524          1.387143  ...               0.0
# 4           29.190000          0.002381  ...         12.150559
# ..                ...               ...  ...               ...
# 633          0.000000          0.000000  ...               0.0
# 634        277.269909        276.704124  ...         280.65758
# 635          0.000000          0.000000  ...               0.0
# 636        161.129934        161.129934  ...        132.381838
# 637        162.466708        162.466708  ...         24.529048
#
#      Mixed_(2025, 12)  Mixed_(2026, 1)  Mixed_(2026, 2)  Mixed_(2026, 3)  \
# 0            0.770476        25.859524         5.386667        16.308571
# 1            1.093333         3.957619       176.160476         0.192381
# 2            7.989012        20.604317         8.240471        20.854519
# 3                 0.0         2.681895         1.455068         2.025624
# 4                 0.0              0.0              0.0              0.0
# ..                ...              ...              ...              ...
# 633               0.0              0.0            0.945              0.0
# 634        266.926005       271.102973       346.356775       301.544498
# 635               0.0              0.0              0.0            3.775
# 636        153.789112        142.01878       150.678581       169.331106
# 637          6.721144        19.769537         1.985431        15.057503
#
#      Mixed_(2026, 4)  Mixed_(2026, 5)  Mixed_(2026, 6)  Mixed_(2026, 7)  \
# 0            9.68381        27.748571         0.450952         9.590476
# 1          10.970952         1.177619         0.034286        14.757143
# 2           8.489422        21.102225          8.73589         21.34746
# 3           0.077343              0.0              0.0          0.33555
# 4                0.0              0.0              0.0              0.0
# ..               ...              ...              ...              ...
# 633              0.0              0.0              0.0              0.0
# 634       210.705014       311.331029       472.507081       259.034729
# 635              0.0              0.0              0.0              0.0
# 636         83.75662       163.672874       353.392403       206.307509
# 637              0.0        10.392471              0.0         5.773973
#
#      Mixed_(2026, 8)
# 0          43.365714
# 1           0.319048
# 2           8.979899
# 3                0.0
# 4                0.0
# ..               ...
# 633              0.0
# 634       142.410271
# 635              0.0
# 636        153.64732
# 637              0.0
#
# [638 rows x 101 columns]

# %%
if debug==True:
    ax=k.T.iloc[4:28,:].plot()
    ax2=k.T.iloc[28:(28+24),:].plot(ax=ax)
    ax3=k.T.iloc[(28+24):(28+2*24),:].plot(ax=ax2)
    k.T.iloc[(28+2*24):(28+3*24),:].plot(ax=ax3)

# %%
if debug==True:
    pred_ = k.T.iloc[:29,:]
    pred_.columns = k.T.iloc[0:4,:].astype(str).apply('_'.join, axis=0)
    pred_=pred_.iloc[5:29,:]
    dates = pd.date_range(start='2023-03-01', end='2025-03-01', freq='M')
    index = pd.MultiIndex.from_tuples([(date.year, date.month) for date in dates], names=['Ano', 'Mês'])
    pred_.set_index(index, inplace=True)
    # ax=grupo[grupo.mean().sort_values().index].plot(figsize=(20,4))#plota as séries começando com a que tem a menor média
    # pred_.plot(figsize=(20,4),ax=ax)#plota as séries começando com a que tem a menor média
    pd.concat([grupo,pred_]).plot(figsize=(20,20))
    #k.T.iloc[:29,:]

# %%
if debug==True:
    pred_ = k.T.iloc[29:53,:]
    pred_.columns = k.T.iloc[0:4,:].astype(str).apply('_'.join, axis=0)
    dates = pd.date_range(start='2023-03-01', end='2025-03-01', freq='M')
    index = pd.MultiIndex.from_tuples([(date.year, date.month) for date in dates], names=['Ano', 'Mês'])
    pred_.set_index(index, inplace=True)
    # ax=grupo[grupo.mean().sort_values().index].plot(figsize=(20,4))#plota as séries começando com a que tem a menor média
    # pred_.plot(figsize=(20,4),ax=ax)#plota as séries começando com a que tem a menor média
    pd.concat([grupo,pred_]).plot(figsize=(20,20))
    #k.T.iloc[29:53,:]

# %%
if debug==True:
    pred_ = k.T.iloc[53:77,:]
    pred_.columns = k.T.iloc[0:4,:].astype(str).apply('_'.join, axis=0)
    dates = pd.date_range(start='2023-03-01', end='2025-03-01', freq='M')
    index = pd.MultiIndex.from_tuples([(date.year, date.month) for date in dates], names=['Ano', 'Mês'])
    pred_.set_index(index, inplace=True)
    # ax=grupo[grupo.mean().sort_values().index].plot(figsize=(20,4))#plota as séries começando com a que tem a menor média
    # pred_.plot(figsize=(20,4),ax=ax)#plota as séries começando com a que tem a menor média
    pd.concat([grupo,pred_]).plot(figsize=(20,20))
    #k.T.iloc[53:77,:]
